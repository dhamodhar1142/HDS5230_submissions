# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np
from datetime import datetime

# %%
# File Path
DATA_FILE_PATH = "timeseries.csv"

# %%
# Define data types for efficient processing
def define_data_types():
    return {
        "name": "str", "level": "str", "city": "str", "county": "str", "state": "str", "country": "str",
        "population": "float", "lat": "float", "long": "float", "url": "str", "aggregate": "str", "tz": "str",
        "cases": "float", "deaths": "float", "recovered": "str", "active": "str", "tested": "str",
        "hospitalized": "str", "hospitalized_current": "str", "discharged": "str", "icu": "str", "icu_current": "str",
        "growthFactor": "str", "date": "str"
    }

# %%
# Load data as Dask DataFrame
def load_data(file_path):
    data_types = define_data_types()
    return dd.read_csv(file_path, dtype=data_types)

# %%
# Convert date column to datetime format
def format_date_column(df):
    df["date"] = dd.to_datetime(df["date"], format="%Y-%m-%d")
    return df

# %%
# Filter data for the United States
def filter_us_data(df):
    return df[df["country"] == "United States"]

# %%
# Filter data based on date range
def filter_date_range(df, start_date, end_date):
    return df[(df["date"] >= start_date) & (df["date"] <= end_date)]

# %%
# Compute per-capita mortality ranking
def compute_per_capita_mortality(df):
    total_deaths = df.groupby('state')["deaths"].sum().compute()
    avg_population = df.groupby('state')["population"].mean().compute()
    per_capita_mortality = total_deaths / avg_population
    return per_capita_mortality.sort_values(ascending=False)

# %%
# Extract year-month from date
def extract_year_month(date_col):
    return f"{date_col.year}_{date_col.month}"

# %%
# Compute Case Fatality Rate (CFR) by state and month
def compute_cfr(df):
    df["year_month"] = df["date"].apply(extract_year_month)
    total_cases = df.groupby(["state", "year_month"])["cases"].sum().compute()
    total_deaths = df.groupby(["state", "year_month"])["deaths"].sum().compute()
    cfr = (total_deaths / total_cases) * 100
    return cfr.reset_index()

# %%
# Create pivot table for CFR analysis
def create_cfr_pivot_table(cfr_df):
    pivot_table = cfr_df.pivot(index='state', columns='year_month')
    cols = cfr_df.pivot(index='state', columns='year_month').columns.tolist()
    cols = [i[1] for i in cols]
    pivot_table.columns = cols
    expected_columns = [f"2020_{i}" for i in range(1, 13)] + ["2021_1", "2021_2"]
    for col in expected_columns:
        if col not in pivot_table.columns:
            pivot_table[col] = np.nan
    return pivot_table[expected_columns]

# %%
# Rank states based on CFR fluctuations over time
def rank_states_by_cfr_changes(pivot_table):
    pivot_table["total_cfr"] = pivot_table.abs().sum(axis=1)
    pivot_table['rank'] = pivot_table['total_cfr'].rank(ascending=False, method='min')
    return pivot_table.sort_values(by='rank')

# %%
df = load_data(DATA_FILE_PATH)
df = format_date_column(df)
df_us = filter_us_data(df)

start_date = datetime.strptime("2020-01-01", "%Y-%m-%d")
end_date = datetime.strptime("2021-02-28", "%Y-%m-%d")
df_us_filtered = filter_date_range(df_us, start_date, end_date)

# %%
ranked_states = compute_per_capita_mortality(df_us_filtered)
print("Per Capita Mortality Ranking:\n", ranked_states)
# Out:
# Per Capita Mortality Ranking:
#  state
# New York                        6.395701
# Michigan                        3.204753
# Louisiana                       2.735288
# Illinois                        2.043863
# New Jersey                      2.031200
# Georgia                         2.026085
# Pennsylvania                    1.831572
# Virginia                        1.359063
# Mississippi                     1.356705
# Indiana                         1.353423
# Ohio                            1.058943
# Iowa                            0.958771
# Massachusetts                   0.904775
# Colorado                        0.894296
# Minnesota                       0.768853
# Kentucky                        0.751512
# Texas                           0.737643
# Missouri                        0.711146
# Connecticut                     0.677952
# Maryland                        0.658347
# Alabama                         0.599759
# North Carolina                  0.549190
# Florida                         0.545793
# Wisconsin                       0.437617
# Nebraska                        0.397699
# Oklahoma                        0.397603
# Tennessee                       0.375231
# California                      0.371347
# Washington                      0.359377
# Kansas                          0.330341
# New Mexico                      0.327128
# South Carolina                  0.315557
# Arkansas                        0.271762
# Rhode Island                    0.220419
# South Dakota                    0.215476
# North Dakota                    0.204487
# West Virginia                   0.136558
# Nevada                          0.126360
# New Hampshire                   0.123780
# Idaho                           0.118306
# Vermont                         0.101814
# Oregon                          0.098453
# Delaware                        0.095738
# Maine                           0.077630
# Washington, D.C.                0.045661
# Utah                            0.044994
# Wyoming                         0.028398
# Arizona                         0.028349
# Montana                         0.025902
# Alaska                          0.019541
# United States Virgin Islands    0.002364
# Northern Mariana Islands        0.001922
# Hawaii                          0.001786
# Puerto Rico                     0.001670
# Guam                            0.001585
# American Samoa                  0.000000
# NaN                                  NaN
# dtype: float64

# %%
cfr_df = compute_cfr(df_us_filtered)
# Out:
# C:\Users\dhamo\anaconda3\Lib\site-packages\dask_expr\_collection.py:4376: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=('date', 'object'))
#
#   warnings.warn(meta_warning(meta))

# %%
cfr_pivot_table = create_cfr_pivot_table(cfr_df)
cfr_pivot_table
# Out:
#                               2020_1    2020_2    2020_3     2020_4  \
# state
# Alabama                          NaN       NaN  0.532313   2.830899
# Alaska                           NaN       NaN  0.335008   2.314519
# American Samoa                   NaN       NaN       NaN        NaN
# Arizona                          0.0  0.000000  0.000000   1.486545
# Arkansas                         NaN       NaN  0.915656   1.911450
# California                       0.0  0.000000  2.006735   3.479974
# Colorado                         NaN       NaN  0.939250   2.636616
# Connecticut                      NaN       NaN  1.814771   6.477626
# Delaware                         NaN       NaN  1.334107   2.734038
# Florida                          NaN       NaN  0.842669   2.905738
# Georgia                          NaN       NaN  2.185574   3.980977
# Guam                             NaN       NaN  2.702703   3.615483
# Hawaii                           NaN       NaN  0.036271   0.000000
# Idaho                            NaN       NaN  1.448967   2.258980
# Illinois                         0.0  0.000000  1.288155   4.048394
# Indiana                          NaN       NaN  2.396460   4.775795
# Iowa                             NaN       NaN  0.863465   2.326472
# Kansas                           NaN       NaN  0.989866   2.364135
# Kentucky                         NaN       NaN  2.225112   5.074331
# Louisiana                        NaN       NaN  3.916843   5.191232
# Maine                            NaN       NaN  0.529355   3.778067
# Maryland                         NaN       NaN  0.261008   3.684368
# Massachusetts                    NaN  0.000000  0.499505   4.415282
# Michigan                         NaN       NaN  2.493512   7.508176
# Minnesota                        NaN       NaN  0.000000   2.527566
# Mississippi                      NaN       NaN  1.504930   3.296058
# Missouri                         NaN       NaN  1.196568   2.878952
# Montana                          NaN       NaN  0.000000   0.966368
# Nebraska                         NaN  0.000000  0.000000   1.422412
# Nevada                           NaN       NaN  2.033319   4.051924
# New Hampshire                    NaN       NaN  0.268757   1.546978
# New Jersey                       NaN       NaN  0.401749   4.064989
# New Mexico                       NaN       NaN  0.705290   2.949834
# New York                         NaN       NaN  2.075213   6.525716
# North Carolina                   NaN       NaN  0.331498   2.722044
# North Dakota                     NaN       NaN  0.253646   0.893946
# Northern Mariana Islands         NaN       NaN       NaN  14.468085
# Ohio                             NaN       NaN  1.529431   4.404734
# Oklahoma                         NaN       NaN  2.833876   5.439956
# Oregon                           NaN  0.000000  2.660322   3.617323
# Pennsylvania                     NaN       NaN  1.081428   3.292275
# Puerto Rico                      NaN       NaN       NaN   5.808946
# Rhode Island                     NaN       NaN  0.061703   1.516496
# South Carolina                   NaN       NaN  1.964286   2.882223
# South Dakota                     NaN       NaN  0.775194   0.453175
# Tennessee                        NaN       NaN  0.036523   1.964376
# Texas                            NaN  0.000000  1.184979   2.403974
# United States Virgin Islands     NaN       NaN       NaN   5.223881
# Utah                             NaN  0.000000  0.179292   0.446306
# Vermont                          NaN       NaN  3.411633   4.238581
# Virginia                         NaN       NaN  1.406402   2.865308
# Washington                       0.0  1.360544  5.051079   5.255217
# Washington, D.C.                 NaN       NaN  1.436880   3.736434
# West Virginia                    NaN       NaN  0.000000   2.181204
# Wisconsin                        NaN  0.000000  0.852336   4.482942
# Wyoming                          NaN       NaN  0.000000   0.396069
#
#                                  2020_5    2020_6    2020_7  2020_8  2020_9  \
# state
# Alabama                        3.889270  2.962907  2.381771     NaN     NaN
# Alaska                         2.196905  1.303247  1.207417     NaN     NaN
# American Samoa                      NaN       NaN       NaN     NaN     NaN
# Arizona                        1.992175  0.211513  0.973523     NaN     NaN
# Arkansas                       2.129628  1.515155  1.274360     NaN     NaN
# California                     3.983350  3.178666  2.543001     NaN     NaN
# Colorado                       5.372019  5.419220  5.063691     NaN     NaN
# Connecticut                    9.016204  9.383106  9.500807     NaN     NaN
# Delaware                       3.574849  4.164733  4.013148     NaN     NaN
# Florida                        4.277250  3.404313  2.039752     NaN     NaN
# Georgia                        4.452969  4.312292  3.263239     NaN     NaN
# Washington, D.C.                  NaN      NaN      NaN     NaN     NaN
# West Virginia                     NaN      NaN      NaN     NaN     NaN
# Wisconsin                         NaN      NaN      NaN     NaN     NaN
# Wyoming                           NaN      NaN      NaN     NaN     NaN

# %%
ranked_cfr_changes = rank_states_by_cfr_changes(cfr_pivot_table)
print("CFR Change Rankings:\n")
ranked_cfr_changes[["total_cfr", "rank"]]
# Out:
# CFR Change Rankings:
#                               total_cfr  rank
# state
# Northern Mariana Islands      78.230784   1.0
# Michigan                      77.250870   2.0
# Connecticut                   75.385029   3.0
# New York                      65.042837   4.0
# Virginia                      63.583214   5.0
# Alabama                       63.194319   6.0
# Florida                       62.939445   7.0
# West Virginia                 62.921609   8.0
# Idaho                         62.752338   9.0
# Texas                         62.456479  10.0
# Minnesota                     62.422193  11.0
# Iowa                          62.339688  12.0
# North Carolina                62.051408  13.0
# South Carolina                62.016879  14.0
# Tennessee                     61.944328  15.0
# Louisiana                     61.829093  16.0
# North Dakota                  61.808223  17.0
# Alaska                        61.714192  18.0
# Arizona                       61.327514  19.0
# Pennsylvania                  61.268118  20.0
# Puerto Rico                   61.211573  21.0
# Montana                       61.197030  22.0
# Kansas                        61.117026  23.0
# Guam                          61.058086  24.0
# Nebraska                      60.966602  25.0
# South Dakota                  60.937579  26.0
# Wisconsin                     60.910055  27.0
# United States Virgin Islands  60.830529  28.0
# Washington                    60.586897  29.0
# Arkansas                      60.492501  30.0
# Massachusetts                 60.451690  31.0
# California                    60.383451  32.0
# Utah                          59.854945  33.0
# New Jersey                    59.851783  34.0
# Wyoming                       59.647442  35.0
# Maine                         59.461196  36.0
# Hawaii                        58.882012  37.0
# Nevada                        58.854350  38.0
# Indiana                       58.801739  39.0
# Vermont                       58.794549  40.0
# Delaware                      58.641749  41.0
# Oregon                        58.593139  42.0
# Rhode Island                  58.380210  43.0
# Ohio                          58.201315  44.0
# Mississippi                   58.185851  45.0
# Maryland                      58.143593  46.0
# New Mexico                    57.809217  47.0
# Georgia                       57.390104  48.0
# Illinois                      56.653661  49.0
# New Hampshire                 56.540145  50.0
# Washington, D.C.              56.115670  51.0
# American Samoa                56.000000  52.0
# Colorado                      55.861592  53.0
# Oklahoma                      55.818062  54.0
# Missouri                      55.815861  55.0
# Kentucky                      55.436363  56.0

# %% [markdown]
# Parallelization & Distributed Computing Considerations
# ### Dask is used for handling large datasets efficiently:
# Dask delays computation until .compute() is called, making operations more efficient for large datasets.
# Grouping operations (groupby.sum(), groupby.mean()) benefit from parallel execution.
# ### Parallelizing per-capita mortality computation:
# Computing per-capita mortality involves simple aggregations, which are easily parallelizable
# ### Parallelizing CFR computation:
# CFR calculation involves groupby operations on "state" and "year_month", which can be distributed across multiple cores.
# ### Parallelizing CFR fluctuation ranking:
# Ranking operations are relatively lightweight but can still benefit from distributed processing when dealing with millions of records.
